# %% [markdown]
# #Aprendiendo Ruby: desde Python
#
# *Diferencias que voy encontrando entre los dos lenguajes y me llaman la atencion.*
#
# Juanjo Conti
#
# @jjconti
#
# http://www.juanjoconti.com.ar

# %%
File.open('proruby.jpg')
# Out:
# #<File:proruby.jpg>

# %% [markdown]
# ## Principalmente
# - https://www.ruby-lang.org/en/documentation/ruby-from-other-languages/to-ruby-from-python/
#
# - http://rubylearning.com
#
# - http://ruby-doc.com/docs/ProgrammingRuby/
#
# - http://stackoverflow.com/questions/tagged/ruby
#
# - http://www.ruby-doc.org/core-2.1.2/
#
# - http://www.codecademy.com/
#
# ## Algunos detalles
# - http://jafrog.com/2012/10/07/mutable-objects-as-hash-keys-in-ruby.html
# - http://rubylearning.com/blog/2011/07/12/throw-catch-raise-rescue-im-so-confused/
# - http://www.rubyinside.com/21-ruby-tricks-902.html

# %%
RUBY_VERSION
# Out:
# "2.1.2"

# %% [markdown]
# ## ¿Qué muestro?
#
# - ### Ejemplos con tipos de datos (bools, strings, arrays, hashes)
#
# - ### Ejemplos con métodos
#
# - ### Cuestiones sintácticas del lenguaje
#
# - ### Advertencias!

# %% [markdown]
# # Ejemlos con tipos de datos

# %% [markdown]
# ## Todo tiene valor de verdad true excepto false y nil

# %%
def que_es obj
  obj ? "#{obj} es true" : "#{obj} es false"
end

que_es []
# Out:
# "[] es true"

# %%
que_es 1
# Out:
# "1 es true"

# %%
que_es false
# Out:
# "false es false"

# %% [markdown]
# ## Los strings son mutables

# %%
s = "Cactus"
s[0] = 'KKKK'
s
# Out:
# "KKKKactus"

# %% [markdown]
# ## Conversión de tipos mediante métodos

# %%
"hola".to_i
# Out:
# 0

# %%
".5".to_f
# Out:
# 0.5

# %%
" 1.5    -  fffffff ".to_f
# Out:
# 1.5

# %%
"..... 1.54    -  fffffff ".to_f
# Out:
# 0.0

# %% [markdown]
# ## Arrays y sus índices

# %%
a = []
a[4] = 1
a
# Out:
# [nil, nil, nil, nil, 1]

# %%
a[10]

# %% [markdown]
# ## Objetos mutables como valor por defecto en un array

# %%
arr = Array.new(3, {})
# Out:
# [{}, {}, {}]

# %%
arr[1][:a] = 1
arr
# Out:
# [{:a=>1}, {:a=>1}, {:a=>1}]

# %% [markdown]
# ## Array * string

# %%
array = [1, 2, 3, 4, 100]
array * 2
# Out:
# [1, 2, 3, 4, 100, 1, 2, 3, 4, 100]

# %%
array * '|'
# Out:
# "1|2|3|4|100"

# %%
[1, [2,3], 4, [[[5]]]] * ','
# Out:
# "1,2,3,4,5"

# %% [markdown]
# ## Los hashes recuerdan el orden de inserción

# %%
h = {}
h[9] = 6
h[8] = 7
h[7] = 8
h.delete(8)
h[8] = 7
h.keys
# Out:
# [9, 7, 8]

# %% [markdown]
# ## Se pueden usar objetos mutables como claves

# %%
a = []
h = {a => 2}
h.default = 'defecto'
a << 1
h
# Out:
# {[1]=>2}

# %%
h[a]
# Out:
# "defecto"

# %%
h.rehash
h[a]
# Out:
# 2

# %% [markdown]
# ## Tratamiento especial de strings al usarlos como claves
# A pesar de que son objetos mutables, al usarlos como claves, se realiza una copia de ellos y se freeza.

# %%
key = 'a'
hash = {key => 1}
# Out:
# {"a"=>1}

# %%
key.upcase!
# Out:
# "A"

# %%
hash
# Out:
# {"a"=>1}

# %%
key.object_id
# Out:
# 84604640

# %%
hash.keys[0].object_id
# Out:
# 84604610

# %% [markdown]
# # Ejemplos con métodos

# %% [markdown]
# ### chop vs. chomp

# %%
"hola".chop
# Out:
# "hol"

# %%
"hola".chomp
# Out:
# "hola"

# %%
"hola\n".chomp
# Out:
# "hola"

# %% [markdown]
# ### map y collect son alias

# %%
[1, 2, 3].map {|x| x * 2}
# Out:
# [2, 4, 6]

# %%
[1, 2, 3].collect {|x| x * 2}
# Out:
# [2, 4, 6]

# %% [markdown]
# ### count, size y lenght

# %%
array = ['hola', 3, Object.new]
array.size
# Out:
# 3

# %%
array.count
# Out:
# 3

# %%
array.length
# Out:
# 3

# %%
array[10] = 1
array
# Out:
# ["hola", 3, #<Object:0x9e7b39c>, nil, nil, nil, nil, nil, nil, nil, 1]

# %%
[array.size, array.count, array.length]
# Out:
# [11, 11, 11]

# %% [markdown]
# ### to_s o to_str, to_i o to_int

# %%
[1.to_s, "5".to_i]
# Out:
# ["1", 5]

# %%
"1".to_int
# Out:
# NoMethodError: undefined method `to_int' for "1":String
# (pry):62:in `<main>'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:353:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:353:in `evaluate_ruby'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:321:in `handle_line'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:241:in `block (2 levels) in eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:240:in `catch'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:240:in `block in eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:239:in `catch'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:239:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/backend.rb:28:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/kernel.rb:110:in `execute_request'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/kernel.rb:62:in `run'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/command.rb:30:in `run_kernel'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/command.rb:16:in `run'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/bin/iruby:6:in `<top (required)>'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/iruby:23:in `load'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/iruby:23:in `<main>'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/ruby_executable_hooks:15:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/ruby_executable_hooks:15:in `<main>'

# %%
class MyInt
  def to_int
    0
  end
end

[1, 2][MyInt.new]
# Out:
# 1

# %% [markdown]
# ## Symbol#to_proc

# %%
['un', 'dos', 'tres'].map(&:upcase)
# Out:
# ["UN", "DOS", "TRES"]

# %%
class Symbol
  def to_proc
    Proc.new {|x| x * 2}
  end
end

['un', 'dos', 'tres'].map(&:upcase)
# Out:
# ["unun", "dosdos", "trestres"]

# %% [markdown]
# # Cuestiones sintácticas

# %% [markdown]
# ## Sintaxis: bloques: { } o do/end
# La regla de estilo dice que se recomiendo usar llaves cuando el bloque es de una línea y do/end cuando es multilínea. Para la elección, también conviene saber que las llaves tienen alta presedencia mientras que do/end baja.

# %%
def come_bloques a
  puts a
  yield
end
# Out:
# :come_bloques

# %%
come_bloques 1 { puts 2}
# Out:
# SyntaxError: unexpected '{', expecting end-of-input
# come_bloques 1 { puts 2}
#                 ^

# %%
come_bloques(1) { puts 2}
# Out:
# 1
# 2

# %%
come_bloques 1 do puts 2 end
# Out:
# 1
# 2

# %% [markdown]
# ## Sintaxis: el parser ve aunque no ejecute
# Para saber que existe una variable, no necesita haber ejecutado su asginación. Alcanza con que el parser la haya visto.

# %%
q.nil?
# Out:
# NameError: undefined local variable or method `q' for main:Object
# (pry):84:in `<main>'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:353:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:353:in `evaluate_ruby'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:321:in `handle_line'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:241:in `block (2 levels) in eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:240:in `catch'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:240:in `block in eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:239:in `catch'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:239:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/backend.rb:28:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/kernel.rb:110:in `execute_request'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/kernel.rb:62:in `run'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/command.rb:30:in `run_kernel'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/command.rb:16:in `run'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/bin/iruby:6:in `<top (required)>'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/iruby:23:in `load'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/iruby:23:in `<main>'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/ruby_executable_hooks:15:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/ruby_executable_hooks:15:in `<main>'

# %%
q = 1 if q.nil?
# Out:
# 1

# %%
if false
  f = 1
end
f.inspect
# Out:
# "nil"

# %% [markdown]
# ## Sintaxis: parámetros con valores por defecto referenciando parámetros previos

# %%
def parametros a, b=a*2
  [a, b]
end

parametros 10
# Out:
# [10, 20]

# %% [markdown]
# ## Sintaxis: *expresion* if *condición*

# %%
a = 1 if true
# Out:
# 1

# %% [markdown]
# Como if es también una expresión, lo siguiente es válido:

# %%
if true
  puts "no no no no"
end if false

# %% [markdown]
# # Advertencias!

# %% [markdown]
# ## Comas al final de una línea (!)

# %%
config = {
  A1: 1,
  B2: 2
}
# Out:
# {:A1=>1, :B2=>2}

# %%
A1 = 1,
B2 = 2
A1
# Out:
# [1, 2]

# %% [markdown]
# ## Espacios en blanco (!)

# %%
C1 = 'A'
C2 = 'B'
C1 + C2
# Out:
# "AB"

# %%
'A' +C2
# Out:
# "AB"

# %%
C1 +C2
# Out:
# NoMethodError: undefined method `+@' for "B":String
# (pry):110:in `<main>'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:353:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:353:in `evaluate_ruby'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:321:in `handle_line'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:241:in `block (2 levels) in eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:240:in `catch'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:240:in `block in eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:239:in `catch'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/pry-0.10.0/lib/pry/pry_instance.rb:239:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/backend.rb:28:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/kernel.rb:110:in `execute_request'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/kernel.rb:62:in `run'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/command.rb:30:in `run_kernel'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/lib/iruby/command.rb:16:in `run'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/gems/iruby-0.1.11/bin/iruby:6:in `<top (required)>'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/iruby:23:in `load'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/iruby:23:in `<main>'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/ruby_executable_hooks:15:in `eval'
# /home/juanjo/.rvm/gems/ruby-2.1.2@watu/bin/ruby_executable_hooks:15:in `<main>'

# %% [markdown]
# ## No uso de paréntesis (!)
#
# El uso de paréntesis al llamar a métodos sirve no solo para aumentar la legibilidad del código sino también para ayudar al parser a tomar decisiones correctas en situaciones ambiguas.
#
# Respuesta de Matthew Kerwin en ruby-talk.

# %%
def a(*args) p [:a, *args]; end
def b(*args) p [:b, *args]; end
def C(*args) p [:C, *args]; end
b = 1
C = 99
# Out:
# 99

# %%
a +1
# Out:
# 2

# %%
C +1
# Out:
# [:C, 1]
# [:C, 1]

# %%
a + 1
# Out:
# 2

# %%
b + 1
# Out:
# 2

# %%
C + 1
# Out:
# 100

# %% [markdown]
# #FIN

# %% [markdown]
# #Muchas gracias!

# %% [markdown]
# #¿Preguntas?

# %% [markdown]
# * ## ¿Qué usaste para hacer las *slides*?

# %% [markdown]
# * ### IPython (ahora llamado Jupyter) con el kernel IRuby y el plugin live_reveal (reveal.js)

# %% [markdown]
# * ## ¿De dónde se pueden bajar las slides?

# %% [markdown]
# * ### juanjoconti.com.ar
# * ### github.com/jjconti
